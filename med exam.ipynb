# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
df_data = pd.read_csv('data exam.csv')
df_data[['name','club','age','position','position_cat','market_value','page_views','fpl_value','fpl_sel','fpl_points','region','nationality','new_foreign','age_cat','club_id','big_club','new_signing']]
# Out:
#                         name         club  age position  position_cat  \
# 0             Alexis Sanchez      Arsenal   28       LW             1
# 1                 Mesut Ozil      Arsenal   28       AM             1
# 2                  Petr Cech      Arsenal   35       GK             4
# 3               Theo Walcott      Arsenal   28       RW             1
# 4          Laurent Koscielny      Arsenal   31       CB             3
# 5            Hector Bellerin      Arsenal   22       RB             3
# 6             Olivier Giroud      Arsenal   30       CF             1
# 7              Nacho Monreal      Arsenal   31       LB             3
# 8           Shkodran Mustafi      Arsenal   25       CB             3
# 9                 Alex Iwobi      Arsenal   21       LW             1
# 10              Granit Xhaka      Arsenal   24       DM             2
# 11   Alex Oxlade-Chamberlain      Arsenal   23       RM             2
# ...

# %%
df_data.head(6)
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
# 5    Hector Bellerin  Arsenal   22       RB             3          30.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264     3.0           Chile
# 1        4395        9.5   5.60%         167     2.0         Germany
# 2        1529        5.5   5.90%         134     2.0  Czech Republic
# 3        2393        7.5   1.50%         122     1.0         England
# 4         912        6.0   0.70%         121     2.0          France
# ...

# %%
df_data2 = df_data[['market_value']]
df_data2
# Out:
#      market_value
# 0           65.00
# 1           50.00
# 2            7.00
# 3           20.00
# 4           22.00
# 5           30.00
# 6           22.00
# 7           13.00
# 8           30.00
# 9           10.00
# 10          35.00
# 11          22.00
# 12          18.00
# 13          35.00
# 14          15.00
# 15          13.00
# 16          10.00
# 17          12.00
# 18          15.00
# 19           7.00
# 20          10.00
# 21          15.00
# 22           1.00
# 23           7.00
# 24           5.00
# 25           6.00
# 26          15.00
# 27          40.00
# 28           8.00
# 29           5.00
# ..            ...
# 431         10.00
# 432          4.00
# 433          3.00
# 434          2.50
# 435          1.50
# 436          0.25
# 437          1.50
# 438          1.00
# 439          8.00
# 440         15.00
# 441         18.00
# 442         10.00
# 443          7.00
# 444         18.00
# 445         12.00
# 446          7.00
# 447          2.50
# 448          2.00
# ...

# %%
df_data1 = df_data[['page_views']]
df_data1
# Out:
#      page_views
# 0          4329
# 1          4395
# 2          1529
# 3          2393
# 4           912
# 5          1675
# 6          2230
# 7           555
# 8          1877
# 9          1812
# 10         1815
# 11         1519
# 12         1759
# 13         1040
# 14          549
# 15          552
# 16          489
# 17          943
# 18         1521
# 19          666
# 20          683
# 21         2055
# 22          372
# 23          544
# 24          561
# 25          702
# 26          618
# 27         1183
# 28          997
# 29         3213
# ..          ...
# 431         472
# 432         165
# 433         454
# 434         766
# 435         169
# 436          15
# 437         100
# 438          82
# 439        1210
# 440         493
# 441        1142
# 442         338
# 443         867
# 444         845
# 445         284
# 446         425
# 447         459
# 448         187
# 449        1212
# 450         266
# 451         380
# 452         286
# 453         394
# ...

# %%
df_data1.sort_values(by=["page_views"])
# Out:
#      page_views
# 184           3
# 328           9
# 436          15
# 70           22
# 61           23
# 161          36
# 60           52
# 327          53
# 157          53
# 162          56
# 188          56
# 176          63
# 165          65
# 293          65
# 167          67
# 90           68
# 169          70
# 163          73
# 417          74
# 174          75
# 177          81
# 171          81
# 438          82
# 373          82
# 168          83
# 164          84
# 180          85
# 179          85
# 67           87
# 56           88
# ..          ...
# 6          2230
# 240        2252
# 265        2280
# 245        2302
# 248        2318
# 100        2378
# 3          2393
# 268        2430
# 102        2537
# 336        2656
# 99         2745
# 214        2958
# 189        2988
# 95         3069
# 29         3213
# 215        3219
# 271        3312
# 270        3668
# 260        3727
# 104        4042
# 241        4046
# 377        4161
# 92         4220
# ...

# %%
df_data1.head(6)
# Out:
#    page_views
# 0        4329
# 1        4395
# 2        1529
# 3        2393
# 4         912
# 5        1675

# %%
sns.set()
_=plt.hist(df_data['market_value'], bins = bin_edges)
_=plt.xlabel('')
_=plt.ylabel('')

plt.show()

# %%
A large number of players a few salaries ranging from 0 to 20 and very few players high salary.
# Out:
#   File "<ipython-input-59-5c572fa29930>", line 1
#     A large number of players a few salaries ranging from 0 to 20 and very few players high salary.
#           ^
# SyntaxError: invalid syntax

# %%
_= sns.swarmplot(x='fpl_value',y='fpl_points', data=df_data)
_=plt.xlabel('value')
_=plt.ylabel('points')
plt.show()

# %%
_= sns.swarmplot(x='position',y='market_value', data=df_data)
_=plt.xlabel('')
_=plt.ylabel('')
plt.show()

# %%
sns.set()
_=plt.hist(df_data['page_views'], bins = bin_edges)
_=plt.xlabel('')
_=plt.ylabel('')

plt.show()

# %%
_= sns.swarmplot(x='market_value',y='age', data=df_data)
_=plt.xlabel('Market Value')
_=plt.ylabel('Age')
plt.show()

# %%
_= sns.swarmplot(x='position',y='position_cat', data=df_data)
_=plt.xlabel('position')
_=plt.ylabel('position_cat')
plt.show()
